# %% [markdown]
# # Splošna analiza
#
# Tu se nahaja splošna analiza najnovejših podatkov vzorcev s spletne strani [Lovecrafts](https://www.lovecrafts.com/en-gb/). Za razlago posamezne funkcije je treba miško zadržati nad imenom funkcije, oziroma pogledati dokument funkcije_za_analizo.py (v datoteki podrobna_analiza), če gledate analizo na spletu.

# %% [markdown]
# ## Priprava na analizo

# %%
import sys
sys.path.append('..') 
from podrobna_analiza.funkcije_za_analizo import *

# %%
precisti_vrste_izdelkov()

# %%
vzorci.count()
# Out:
# Ime                3000
# Priljubljenost     3000
# Cena [£]           3000
# Vrsta izdelka      2768
# Podjetje           3000
# Avtor              2547
# Jezik              2998
# Število vzorcev    2963
# Število strani     2220
# Raven znanja       2781
# dtype: int64

# %% [markdown]
# ## Manjkajoči podatki

# %% [markdown]
# > *Opomba*: Ko govorim o nižji ali manjši priljubljenosti, pravzaprav mislim, da ima višje število kot podatek in nasprotno za višjo ali večjo priljubljenost, ker manjše število pomeni, da je vzorec bolj priljubljen.

# %%
korelacija_manjkanja_in_nizje_('Priljubljenost')
# Out:
# Korelacija z nižjo priljubljenostjo:
# 	- Vrsta izdelka manjka: 0.014
# 	- Avtor manjka: 0.186
# 	- Jezik manjka: 0.008
# 	- Število vzorcev manjka: 0.005
# 	- Število strani manjka: 0.043
# 	- Raven znanja manjka: 0.171

# %%
korelacija_manjkanja_in_nizje_('Cena [£]')
# Out:
# Korelacija z nižjo ceno:
# 	- Vrsta izdelka manjka: 0.089
# 	- Avtor manjka: 0.278
# 	- Jezik manjka: 0.021
# 	- Število vzorcev manjka: 0.004
# 	- Število strani manjka: -0.008
# 	- Raven znanja manjka: 0.191

# %% [markdown]
# ## Povezava med ceno in priljubljenostjo

# %%
korelacija_cena_priljubljenost()
# Out:
# Korelacija med ceno in priljubljenostjo: 0.506

# %%
cena_priljubljenost()

# %%
koliko_placljivih_vzorcev()
# Out:
# Plačljivih vzorcev je: 1398

# %% [markdown]
# ## Avtorji

# %%
povprecja_napisanih_vzorcev(100, 'Priljubljenost')
# Out:
# Vsi avtorji
# Aritmetična sredina: 2.43
# Mediana: 1.0
#
# Avtorji najbolj priljubljenih vzorcev:
# Aritmetična sredina: 8.24
# Mediana: 5.0

# %%
stevilo_objavljenih_vzorcev(10, 'Priljubljenost')
# Out:
# Avtor: število objavljenih vzorcev
# KATE EASTWOOD: 7
# Jade Gauthier-Boutin: 17
# Little Fig: 9
# annelies baes: 3
# Frisian Knitting: 3
# Little Golden Nook: 3
# K.A.M.E. Crochet: 21

# %%
povprecja_napisanih_vzorcev(100, 'Cena [£]')
# Out:
# Vsi avtorji
# Aritmetična sredina: 2.43
# Mediana: 1.0
#
# Avtorji najbolj dragih vzorcev:
# Aritmetična sredina: 4.17
# Mediana: 3.0

# %%
stevilo_objavljenih_vzorcev(10, 'Cena [£]')
# Out:
# Avtor: število objavljenih vzorcev
# isWoolish: 22
# Crochet to Play: 1
# KATE EASTWOOD: 7
# Soft threads93: 6
# RaffamusaDesigns: 7
# Danielle Magalhães: 9
# Stephanie Tejidos: 3
# Melody Rogers: 1
# Bonnie Bay Crochet: 10
# Galina Litvinova: 2

# %%
stevilo_del_avtorjev(30)
# Out:
# Največ napisanih vzorcev s strani enega avtorja: 51. To predstavlja 1.70% vseh vzorcev

# %% [markdown]
# ## Potrebna raven znanja

# %%
stevec('Raven znanja')
# Out:
# Raven znanja
# Beginner             1384
# Intermediate         1313
# Advanced               71
# Advanced Beginner      13
# Name: count, dtype: int64

# %%
primerjava('Raven znanja', 'Priljubljenost')

# %%
primerjava('Raven znanja', 'Cena [£]')

# %% [markdown]
# ## Vrsta izdelka

# %%
stevec('Vrsta izdelka')
# Out:
# Vrsta izdelka
# Toys                       646
# Homeware                   477
# Accessories                420
# Tops                       216
# Cardigans                  202
# Blankets                   145
# Hats                        96
# Sweaters                    85
# Dresses                     71
# Baby Hats                   56
# Cushions                    45
# Shawls                      42
# Jumpers                     40
# Ponchos                     26
# Amigurumi                   24
# Decorations                 21
# Waistcoats                  20
# Booties                     18
# Jackets                     16
# Headbands                   14
# Boleros                     13
# Socks                       13
# Granny squares              12
# Scarves & Shawls            12
# Coats                       10
# Pet Clothing                 4
# Slippers                     3
# Home                         3
# Baby Blankets                2
# Gloves & Mittens             2
# Dishcloths                   2
# Pet Bedding                  2
# Skirts                       2
# Cowls                        2
# Vests Knitting Patterns      2
# Bags                         1
# Table Setting                1
# Other                        1
# Baby Clothes                 1
# Name: count, dtype: int64

# %%
primerjava('Vrsta izdelka', 'Priljubljenost')

# %%
primerjava('Vrsta izdelka', 'Cena [£]')

# %% [markdown]
# ## Jeziki

# %%
stevec_jezikov()
# Out:
# Jezik
# English                    2974
# German                      141
# French                      103
# Dutch                        75
# Spanish                      37
# Russian                      16
# Portuguese                   12
# Danish                        9
# Swedish                       7
# Italian                       5
# Polish                        5
# Diagrams/chartsonly           5
# suitableforalllanguages       5
# Finnish                       3
# Hungarian                     2
# Afrikaans                     2
# Hebrew                        2
# Norwegian                     1
# Czech                         1
# Indonesian                    1
# Japanese                      1
# Estonian                      1
# Name: count, dtype: int64

# %%
jezik_in('Priljubljenost')

# %%
jezik_in('Cena [£]')

# %% [markdown]
# ## Podjetja

# %%
stevec('Podjetje')
# Out:
# Podjetje
# Independent Designer       2287
# Caron                       131
# Paintbox Yarns              123
# Bernat                      104
# Lion Brand                   58
# Adriafil                     44
# Schachenmayr                 40
# Lily Sugar 'n Cream          38
# Cascade Yarns                26
# Sirdar                       20
# King Cole                    17
# Berroco                      14
# Red Heart                    11
# Rowan                        11
# Debbie Bliss                 10
# Patons US                    10
# Hoooked                       8
# Stylecraft                    8
# Wool and the Gang             5
# West Yorkshire Spinners       5
# Hayfield                      4
# Lana Grossa                   4
# Plymouth Yarn                 4
# Scheepjes                     3
# Sirdar Snuggly                2
# Valley Yarns                  2
# Yarn and Colors               2
# Patons                        1
# Gründl Wolle                  1
# MillaMia                      1
# DMC                           1
# Schoeller und Stahl           1
# Bergère de France             1
# Spud and Chloe                1
# Ella Rae                      1
# BC Garn                       1
# Name: count, dtype: int64

# %%
delez('Podjetje')

# %%
posamezni_proti_zbirki('Podjetje', 'Priljubljenost')

# %%
posamezni_proti_zbirki('Podjetje', 'Cena [£]')

# %%
povprecje_napisanih_vzorcec_podjetij()
# Out:
# Podjetja:
# Aritmetična sredina: 20.37
# Mediana: 5.0
#
# Neodvisni avtorji
# Aritmetična sredina: 2.39
# Mediana: 1.0

# %% [markdown]
# ## Število vzorcev

# %%
stevec('Število vzorcev')
# Out:
# Število vzorcev
# 1.0     2839
# 2.0       65
# 3.0       26
# 5.0       10
# 4.0        9
# 6.0        5
# 7.0        4
# 8.0        2
# 11.0       1
# 13.0       1
# 9.0        1
# Name: count, dtype: int64

# %%
delez('Število vzorcev')

# %%
posamezni_proti_zbirki('Število vzorcev', 'Priljubljenost')

# %%
posamezni_proti_zbirki('Število vzorcev', 'Cena [£]')
